# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# ## data generation

# %%
import random
import math 
import matplotlib.pyplot as plt

# %%
random.seed(12345)
# step: dx, DX (typical scale of dx), bias (bias of dx)
# P(dx) sim exp( - |dx-bias| / DX )
# lambda 
dx = lambda DX, bias: int( (math.log(random.random()) * DX) * 
                         2*(random.randint(0,1)-0.5) + bias)
for i in range(10):
    print(dx(50,5))
# Out:
# 48
# -4
# 12
# -60
# 96
# -1
# 33
# 29
# 56
# -26

# %%
# pattern: amplitude a, number of bins z (steps)
def pattern(i,z,a):
    return int(a * math.sin((math.pi*i)/z))

# %%
random.seed(12345)
# Amplitude
A = 50 
# Length
Z = 12 

# sample length 
L = 60 
# number of data sample
N = 10000
# step parameters
DX = 50
bias = 5

y = [0] * N
x = [[0] * L for i in range(N)]

for i in range(N):
    if i>0: 
        x[i][0] = x[i-1][-1]
        
    for j in range(1,L):
        x[i][j] = x[i][j-1] + dx(DX,bias)
        
    y[i] = i%3
    if y[i]>0:
        j0 = random.randint(0,L-1-Z)
        sign = 3-2*y[i]
        for j in range(Z):
            x[i][j0+j] += sign*pattern(j,Z,A)
            
for i in range(3):
    print(x[i],y[i])

plt.plot(x[0])
plt.plot(x[1])
plt.plot(x[2])

plt.show()
# Out:
# [0, 48, 44, 56, -4, 92, 91, 124, 153, 209, 183, 214, 314, 236, 185, 136, 424, 442, 385, 502, 522, 524, 539, 438, 519, 457, 494, 658, 722, 821, 774, 687, 909, 931, 983, 977, 1058, 1099, 890, 839, 848, 903, 937, 907, 985, 1080, 1116, 1025, 1036, 975, 845, 893, 902, 727, 818, 909, 911, 972, 999, 1027] 0
# [1027, 1046, 996, 1104, 1042, 1203, 1231, 1328, 1269, 1256, 1202, 1149, 1130, 1187, 1256, 1288, 1472, 1472, 1390, 1312, 1293, 1158, 1200, 1236, 1116, 1049, 1134, 1247, 1241, 1292, 1226, 1326, 1264, 1177, 1345, 1468, 1444, 1449, 1466, 1445, 1476, 1442, 1632, 1630, 1654, 1602, 1453, 1411, 1519, 1496, 1503, 1532, 1533, 1547, 1514, 1660, 1660, 1679, 1731, 1735] 1
# [1735, 1745, 1659, 1672, 1698, 1715, 1748, 1870, 1798, 1729, 1719, 1744, 1770, 1743, 1677, 1664, 1631, 1567, 1614, 1531, 1602, 1584, 1403, 1413, 1407, 1234, 1189, 1267, 1341, 1551, 1611, 1608, 1634, 1549, 1538, 1524, 1496, 1533, 1520, 1534, 1552, 1585, 1536, 1548, 1516, 1539, 1559, 1564, 1583, 1565, 1479, 1479, 1393, 1375, 1338, 1273, 1097, 1068, 1066, 1082] 2

# %%
# create folder DATA
import subprocess, csv
# linux
subprocess.run(["mkdir","DATA"])
# Out:
# CompletedProcess(args=['mkdir', 'DATA'], returncode=1)

# %%
# write on csv file
str0 = f'ts_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.csv'
print(str0)

fname = 'DATA/x_'+str0

with open(fname, mode='w') as myfile:
    writer = csv.writer(myfile, delimiter=',')
    for i in range(N):
        writer.writerow(x[i])
        
fname = 'DATA/y_'+str0

with open(fname, mode='w') as myfile:
    writer = csv.writer(myfile, delimiter=',')
    writer.writerows(map(lambda yy: [yy],y))
# Out:
# ts_L60_Z12_A50_DX50_bias5_N10000.csv

# %% [markdown]
# ## model

# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
# Out:
# Using TensorFlow backend.

# %%
str0 = 'ts_L60_Z12_A50_DX50_bias5_N10000.csv'

fnamex = 'DATA/x_'+str0
fnamey = 'DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=',', dtype=float)
N = len(x)
print(N)

xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

x /= 100    # lazy version of dividing by variance

plt.plot(x[0])
plt.plot(x[1])
plt.plot(x[2])
plt.show()

categ = np.loadtxt(fnamey, delimiter=',', dtype=int)
n_class = 3

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.

perc_train = 0.8

N_train = int(N*perc_train)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(y_val)

L = len(x[0])
print('N_train =',N_train,'   N_val =', N_val, '   L =', L,'    n_class =', n_class)
# Out:
# 10000
# N_train = 8000    N_val = 2000    L = 60     n_class = 3

# %% [markdown]
#  ## Data reshaping

# %%
x_train = x_train.reshape(x_train.shape[0],L,1)
x_val = x_val.reshape(x_val.shape[0],L,1)
input_shape = (L,1)

# %% [markdown]
# ## Convolutional NN

# %%
from keras import initializers, regularizers

# %%
ini = keras.initializers.RandomNormal(mean=0,stddev=0.05,seed=12345)

reg = keras.regularizers.l1(0.1)

NCONV = 1

model = Sequential(name='Diff_process')

if NCONV==1: #0.8865000009536743
    model.add(Conv1D(filters=5, kernel_size=11, kernel_initializer=ini, kernel_regularizer=reg, 
                     activation='relu', input_shape=input_shape))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, activation='relu'))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.2))

if NCONV==2: # Non cambia nulla 0.8865000009536743
    model.add(Conv1D(filters=5, kernel_size=11, 
                    kernel_initializer=ini,
                    activation='relu',
                    input_shape=input_shape))
    model.add(AveragePooling1D(5))
    #model.add(Conv1D(filters=5, kernel_size=7, activation='relu'))
    model.add(Flatten())
    model.add(Dense(8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dropout(0.2))

if NCONV==3: # 0.8980000019073486
    model.add(Conv1D(filters=5, kernel_size=15, 
                    kernel_initializer=ini,
                    activation='relu',
                    input_shape=input_shape))
    model.add(MaxPooling1D(5))
    #model.add(Conv1D(filters=5, kernel_size=7, activation='relu'))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(8, activation='relu'))
    
    
model.add(Dense(n_class, activation='softmax'))
#model.add(Dense(n_class, activation='sign'))

print(model.summary())

from keras import optimizers 
opt = optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True, decay=1e-6)
opt = optimizers.RMSprop()
opt = optimizers.Adam()
opt = optimizers.Nadam()

# model: categorical
model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer=opt,metrics=['accuracy'])
# Out:
# Model: "Diff_process"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 50, 5)             60
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 10, 5)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 5)              180
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                210
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 483
# Trainable params: 483
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Fitting the CNN

# %%
batch_size = 250
epochs = 500

fit = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val,y_val),
                verbose=2, shuffle = True)

print('Max accuracy:', np.array(fit.history['val_accuracy']).max())
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/500
#  - 0s - loss: 1.2295 - accuracy: 0.3279 - val_loss: 1.1421 - val_accuracy: 0.3350
# Epoch 2/500
#  - 0s - loss: 1.1143 - accuracy: 0.3223 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 3/500
#  - 0s - loss: 1.1019 - accuracy: 0.3274 - val_loss: 1.1020 - val_accuracy: 0.3335
# Epoch 4/500
#  - 0s - loss: 1.1018 - accuracy: 0.3335 - val_loss: 1.1027 - val_accuracy: 0.3325
# Epoch 5/500
#  - 0s - loss: 1.1019 - accuracy: 0.3225 - val_loss: 1.1023 - val_accuracy: 0.3330
# Epoch 6/500
#  - 0s - loss: 1.1018 - accuracy: 0.3340 - val_loss: 1.1024 - val_accuracy: 0.3335
# Epoch 7/500
#  - 0s - loss: 1.1019 - accuracy: 0.3332 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 8/500
#  - 0s - loss: 1.1018 - accuracy: 0.3260 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 9/500
#  - 0s - loss: 1.1018 - accuracy: 0.3262 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 10/500
#  - 0s - loss: 1.1018 - accuracy: 0.3231 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 11/500
#  - 0s - loss: 1.1018 - accuracy: 0.3210 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 12/500
#  - 0s - loss: 1.1017 - accuracy: 0.3195 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 13/500
#  - 0s - loss: 1.1017 - accuracy: 0.3223 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 14/500
#  - 0s - loss: 1.1017 - accuracy: 0.3232 - val_loss: 1.1023 - val_accuracy: 0.3335
# Epoch 15/500
#  - 0s - loss: 1.1017 - accuracy: 0.3304 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 16/500
#  - 0s - loss: 1.1017 - accuracy: 0.3289 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 17/500
#  - 0s - loss: 1.1017 - accuracy: 0.3232 - val_loss: 1.1022 - val_accuracy: 0.3335
# Epoch 18/500
#  - 0s - loss: 1.1017 - accuracy: 0.3311 - val_loss: 1.1022 - val_accuracy: 0.3330
# Epoch 19/500
#  - 0s - loss: 1.1003 - accuracy: 0.3154 - val_loss: 1.1005 - val_accuracy: 0.3335
# Epoch 234/500
#  - 0s - loss: 1.1003 - accuracy: 0.3289 - val_loss: 1.1005 - val_accuracy: 0.3335
# Epoch 235/500
#  - 0s - loss: 1.1003 - accuracy: 0.3268 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 236/500
#  - 0s - loss: 1.1003 - accuracy: 0.3286 - val_loss: 1.1005 - val_accuracy: 0.3330
# Epoch 237/500
#  - 0s - loss: 1.1003 - accuracy: 0.3307 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 238/500
#  - 0s - loss: 1.1003 - accuracy: 0.3221 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 239/500
#  - 0s - loss: 1.1003 - accuracy: 0.3277 - val_loss: 1.1005 - val_accuracy: 0.3330
# Epoch 240/500
#  - 0s - loss: 1.1003 - accuracy: 0.3228 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 241/500
#  - 0s - loss: 1.1003 - accuracy: 0.3261 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 242/500
#  - 0s - loss: 1.1003 - accuracy: 0.3274 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 243/500
#  - 0s - loss: 1.1003 - accuracy: 0.3282 - val_loss: 1.1005 - val_accuracy: 0.3335
# Epoch 244/500
#  - 0s - loss: 1.1003 - accuracy: 0.3319 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 245/500
#  - 0s - loss: 1.1003 - accuracy: 0.3281 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 246/500
#  - 0s - loss: 1.1003 - accuracy: 0.3319 - val_loss: 1.1005 - val_accuracy: 0.3335
# Epoch 247/500
#  - 0s - loss: 1.1003 - accuracy: 0.3228 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 248/500
#  - 0s - loss: 1.1002 - accuracy: 0.3332 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 249/500
#  - 0s - loss: 1.1003 - accuracy: 0.3341 - val_loss: 1.1005 - val_accuracy: 0.3335
# Epoch 250/500
#  - 0s - loss: 1.1002 - accuracy: 0.3244 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 251/500
#  - 0s - loss: 1.1002 - accuracy: 0.3259 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 252/500
#  - 0s - loss: 1.1003 - accuracy: 0.3304 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 253/500
#  - 0s - loss: 1.1002 - accuracy: 0.3298 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 254/500
#  - 0s - loss: 1.1002 - accuracy: 0.3281 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 255/500
#  - 0s - loss: 1.1002 - accuracy: 0.3200 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 256/500
#  - 0s - loss: 1.1002 - accuracy: 0.3334 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 257/500
#  - 0s - loss: 1.1003 - accuracy: 0.3318 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 258/500
#  - 0s - loss: 1.1002 - accuracy: 0.3236 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 259/500
#  - 0s - loss: 1.1002 - accuracy: 0.3334 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 260/500
#  - 0s - loss: 1.1002 - accuracy: 0.3276 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 261/500
#  - 0s - loss: 1.1002 - accuracy: 0.3291 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 262/500
#  - 0s - loss: 1.1002 - accuracy: 0.3280 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 263/500
#  - 0s - loss: 1.1002 - accuracy: 0.3298 - val_loss: 1.1003 - val_accuracy: 0.3330
# Epoch 264/500
#  - 0s - loss: 1.1002 - accuracy: 0.3310 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 265/500
#  - 0s - loss: 1.1002 - accuracy: 0.3319 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 266/500
#  - 0s - loss: 1.1002 - accuracy: 0.3314 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 267/500
#  - 0s - loss: 1.1002 - accuracy: 0.3301 - val_loss: 1.1004 - val_accuracy: 0.3335
# Epoch 268/500
#  - 0s - loss: 1.1002 - accuracy: 0.3334 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 269/500
#  - 0s - loss: 1.1002 - accuracy: 0.3269 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 270/500
#  - 0s - loss: 1.1002 - accuracy: 0.3226 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 271/500
#  - 0s - loss: 1.1002 - accuracy: 0.3240 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 272/500
#  - 0s - loss: 1.1002 - accuracy: 0.3259 - val_loss: 1.1004 - val_accuracy: 0.3330
# Epoch 273/500
#  - 0s - loss: 1.1002 - accuracy: 0.3241 - val_loss: 1.1003 - val_accuracy: 0.3330
# Epoch 274/500
#  - 0s - loss: 1.1002 - accuracy: 0.3294 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 275/500
#  - 0s - loss: 1.1002 - accuracy: 0.3228 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 276/500
#  - 0s - loss: 1.1002 - accuracy: 0.3276 - val_loss: 1.1003 - val_accuracy: 0.3330
# Epoch 277/500
#  - 0s - loss: 1.1002 - accuracy: 0.3291 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 278/500
#  - 0s - loss: 1.1002 - accuracy: 0.3246 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 279/500
#  - 0s - loss: 1.1002 - accuracy: 0.3295 - val_loss: 1.1003 - val_accuracy: 0.3335
# Epoch 280/500
#  - 0s - loss: 1.1002 - accuracy: 0.3319 - val_loss: 1.1003 - val_accuracy: 0.3330
# Epoch 352/500
#  - 0s - loss: 1.1000 - accuracy: 0.3304 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 353/500
#  - 0s - loss: 1.1000 - accuracy: 0.3331 - val_loss: 1.1001 - val_accuracy: 0.3330
# Epoch 354/500
#  - 0s - loss: 1.1000 - accuracy: 0.3334 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 355/500
#  - 0s - loss: 1.1000 - accuracy: 0.3243 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 356/500
#  - 0s - loss: 1.1000 - accuracy: 0.3126 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 357/500
#  - 0s - loss: 1.1000 - accuracy: 0.3246 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 358/500
#  - 0s - loss: 1.1000 - accuracy: 0.3215 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 359/500
#  - 0s - loss: 1.1000 - accuracy: 0.3334 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 360/500
#  - 0s - loss: 1.1000 - accuracy: 0.3275 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 361/500
#  - 0s - loss: 1.1000 - accuracy: 0.3260 - val_loss: 1.1001 - val_accuracy: 0.3330
# Epoch 362/500
#  - 0s - loss: 1.1000 - accuracy: 0.3275 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 363/500
#  - 0s - loss: 1.1000 - accuracy: 0.3269 - val_loss: 1.1001 - val_accuracy: 0.3330
# Epoch 364/500
#  - 0s - loss: 1.1000 - accuracy: 0.3299 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 365/500
#  - 0s - loss: 1.1000 - accuracy: 0.3196 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 366/500
#  - 0s - loss: 1.1000 - accuracy: 0.3252 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 367/500
#  - 0s - loss: 1.1000 - accuracy: 0.3305 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 368/500
#  - 0s - loss: 1.1000 - accuracy: 0.3286 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 369/500
#  - 0s - loss: 1.1000 - accuracy: 0.3295 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 370/500
#  - 0s - loss: 1.1000 - accuracy: 0.3265 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 371/500
#  - 0s - loss: 1.1000 - accuracy: 0.3327 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 372/500
#  - 0s - loss: 1.1000 - accuracy: 0.3249 - val_loss: 1.1001 - val_accuracy: 0.3335
# Epoch 373/500
#  - 0s - loss: 1.0999 - accuracy: 0.3211 - val_loss: 1.1002 - val_accuracy: 0.3330
# Epoch 374/500
#  - 0s - loss: 1.1000 - accuracy: 0.3334 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 375/500
#  - 0s - loss: 1.0999 - accuracy: 0.3334 - val_loss: 1.1002 - val_accuracy: 0.3335
# Epoch 471/500
#  - 0s - loss: 1.0999 - accuracy: 0.3295 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 472/500
#  - 0s - loss: 1.0999 - accuracy: 0.3270 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 473/500
#  - 0s - loss: 1.0998 - accuracy: 0.3186 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 474/500
#  - 0s - loss: 1.0998 - accuracy: 0.3236 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 475/500
#  - 0s - loss: 1.0998 - accuracy: 0.3302 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 476/500
#  - 0s - loss: 1.0998 - accuracy: 0.3198 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 477/500
#  - 0s - loss: 1.0998 - accuracy: 0.3250 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 478/500
#  - 0s - loss: 1.0998 - accuracy: 0.3334 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 479/500
#  - 0s - loss: 1.0999 - accuracy: 0.3248 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 480/500
#  - 0s - loss: 1.0998 - accuracy: 0.3243 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 481/500
#  - 0s - loss: 1.0998 - accuracy: 0.3257 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 482/500
#  - 0s - loss: 1.0998 - accuracy: 0.3296 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 483/500
#  - 0s - loss: 1.0998 - accuracy: 0.3254 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 484/500
#  - 0s - loss: 1.0999 - accuracy: 0.3194 - val_loss: 1.1001 - val_accuracy: 0.3330
# Epoch 485/500
#  - 0s - loss: 1.0998 - accuracy: 0.3311 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 486/500
#  - 0s - loss: 1.0999 - accuracy: 0.3232 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 487/500
#  - 0s - loss: 1.0998 - accuracy: 0.3296 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 488/500
#  - 0s - loss: 1.0999 - accuracy: 0.3315 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 489/500
#  - 0s - loss: 1.0998 - accuracy: 0.3327 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 490/500
#  - 0s - loss: 1.0999 - accuracy: 0.3261 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 491/500
#  - 0s - loss: 1.0998 - accuracy: 0.3295 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 492/500
#  - 0s - loss: 1.0998 - accuracy: 0.3334 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 493/500
#  - 0s - loss: 1.0998 - accuracy: 0.3191 - val_loss: 1.1000 - val_accuracy: 0.3330
# Epoch 494/500
#  - 0s - loss: 1.0998 - accuracy: 0.3334 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 495/500
#  - 0s - loss: 1.0998 - accuracy: 0.3309 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 496/500
#  - 0s - loss: 1.0998 - accuracy: 0.3294 - val_loss: 1.1000 - val_accuracy: 0.3335
# Epoch 497/500
#  - 0s - loss: 1.0998 - accuracy: 0.3290 - val_loss: 1.0999 - val_accuracy: 0.3330
# Epoch 498/500
#  - 0s - loss: 1.0998 - accuracy: 0.3290 - val_loss: 1.0999 - val_accuracy: 0.3335
# Epoch 499/500
#  - 0s - loss: 1.0998 - accuracy: 0.3226 - val_loss: 1.0999 - val_accuracy: 0.3330
# Epoch 500/500
#  - 0s - loss: 1.0998 - accuracy: 0.3318 - val_loss: 1.0999 - val_accuracy: 0.3335
# Max accuracy: 0.33500000834465027

# %%
for obs in ('accuracy','loss'):
    plt.figure(figsize=(6,4))
    plt.plot(fit.history[obs], 'r', label=obs+' of training data')
    plt.plot(fit.history['val_'+obs], 'b--', label=obs+' of validation data')
    plt.title(NCONV)
    plt.xlabel('Epoch')
    plt.ylabel(obs)
    plt.legend()
    plt.ylim(0)
    plt.show()

# %% [markdown]
# ## Weights of the filters of the first layer

# %%
c = ['k','r','y','b','m']
def plot_w(w):
    plt.figure(figsize=(6,4))
    for i in range(len(w)):
        plt.plot(w[i][0], c[i], label=str(i))
    plt.title(NCONV)
    plt.xlabel('index')
    plt.ylabel('weights')
    plt.legend()
    plt.show()
    
w0 = model.layers[0].get_weights()[0]
w01 = model.layers[0].get_weights()[1]
w0T = w0.T
print('w0T=',w0T)
print('w01=',w01)
print(len(w0))
print(len(w0T))
plot_w(w0T)

plt.plot(w01, 'r')
plt.xlabel('filter_nr')
plt.ylabel('bias of layer 0')
plt.show()
# Out:
# w0T= [[[-3.5715927e-04  9.8753982e-05 -3.0425063e-04 -9.9452242e-05
#     3.1256929e-04 -4.9265829e-05 -8.3294610e-05  3.8003598e-04
#     2.2246374e-04  1.0903386e-04 -4.0664780e-04]]
#
#  [[ 4.2020783e-04 -2.7647914e-04 -2.0419485e-04 -2.0271417e-04
#    -1.3666882e-04 -1.6101552e-04  3.3327442e-04  4.4373490e-04
#     2.5981342e-04 -2.7705386e-04 -5.0037302e-04]]
#
#  [[-3.1513028e-04  3.0261342e-04 -2.4658654e-04 -2.6517842e-04
#     3.1210776e-04 -2.6181733e-04 -7.5065647e-05 -2.6940607e-04
#     8.9183100e-05  1.2687853e-04  4.5774708e-05]]
#
#  [[-9.2384289e-07  1.9071609e-04  1.5297584e-04  2.0419659e-04
#     4.2811694e-04  1.2270050e-04 -1.5186024e-04  2.2580614e-05
#    -2.8486681e-04 -2.1406292e-04 -2.4100229e-04]]
#
#  [[-3.8362475e-04  3.8264086e-04 -7.3215662e-05 -3.4532900e-04
#    -6.0705672e-05 -1.8858808e-04  3.6880828e-04 -4.4533052e-04
#    -4.7988116e-04  6.4739812e-05  3.1678611e-04]]]
# w01= [-0.00640032 -0.00144901 -0.00434868  0.03176302 -0.03192977]
# 11
# 5

# %% [markdown]
# # 2 - Confusion matrix

# %%
import seaborn 
from sklearn import metrics

y_pred = model.predict_classes(x_val)

n_labels = 3

y_val1 = []

for i in range(len(y_val)):
    for j in range(n_labels):
        if y_val[i][j]==1:
            y_val1.append(j)   
                       
confusion_matrics = metrics.confusion_matrix(y_val1, y_pred)

# %%
seaborn.heatmap(confusion_matrics, annot=True, cmap="Blues")

# %% [markdown]
# # 3 - Regularization

# %%
ini = keras.initializers.RandomNormal(mean=0,stddev=0.05,seed=12345)

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers

def compile_model(lambda_val = 0.1):  
    reg = keras.regularizers.l1(lambda_val)
    # create the model
    model = Sequential(name='Diff_process')
    model.add(Conv1D(filters=5, kernel_size=11, kernel_initializer=ini, kernel_regularizer=reg, 
                     activation='relu', input_shape=input_shape))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, activation='relu'))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(n_class, activation='softmax'))
    opt = optimizers.Nadam()
    # compile the model
    model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer=opt,metrics=['accuracy'])
    return model

# %%
# call Keras scikit wrapper
model_gridsearch = KerasClassifier(build_fn=compile_model, 
                        epochs=30, 
                        batch_size=100, 
                        verbose=0)

# list of allowed optional arguments for the optimizer, see `compile_model()`
lambda_val = [0.05,0.1,0.20]

# define parameter dictionary
param_grid = dict(lambda_val=lambda_val)
# call scikit grid search module
grid = GridSearchCV(estimator=model_gridsearch, param_grid=param_grid, n_jobs=2, cv=4)
grid_result = grid.fit(x_train,y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %%
model = compile_model(grid_result.best_params_['lambda_val'])

# %%
# Weights of the filters of the first layer
c = ['k','r','y','b','m']
def plot_w(w):
    plt.figure(figsize=(6,4))
    for i in range(len(w)):
        plt.plot(w[i][0], c[i], label=str(i))
    plt.title(NCONV)
    plt.xlabel('index')
    plt.ylabel('weights')
    plt.legend()
    plt.show()
    
w0 = model.layers[0].get_weights()[0]
w01 = model.layers[0].get_weights()[1]
w0T = w0.T
print('w0T=',w0T)
print('w01=',w01)
print(len(w0))
print(len(w0T))
plot_w(w0T)

plt.plot(w01, 'r')
plt.xlabel('filter_nr')
plt.ylabel('bias of layer 0')
plt.show()

# %%
# Weights of the filters of the second layer
c = ['k','r','y','b','m']
def plot_w(w):
    plt.figure(figsize=(6,4))
    for i in range(len(w)):
        plt.plot(w[i][0], c[i], label=str(i))
    plt.title(NCONV)
    plt.xlabel('index')
    plt.ylabel('weights')
    plt.legend()
    plt.show()
    
w0 = model.layers[2].get_weights()[0]
w01 = model.layers[2].get_weights()[1]
w0T = w0.T
print('w0T=',w0T)
print('w01=',w01)
print(len(w0))
print(len(w0T))
plot_w(w0T)

plt.plot(w01, 'r')
plt.xlabel('filter_nr')
plt.ylabel('bias of layer 0')
plt.show()
